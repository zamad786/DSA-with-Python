# %% [markdown]
# <a href="https://colab.research.google.com/github/zamad786/DSA-with-Python/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = []
a.append(1)
a.append(2)
a.append(4)
a.append(7)
print(a)
a.pop(-1)
print(a)
b = a[1]
print(b)
c = not bool(a)
print("Lets check it is empty: ", c)
print("Lets know the size of stack: ", len(a))
# Out:
# [1, 2, 4, 7]
# [1, 2, 4]
# 2
# Lets check it is empty:  False
# Lets know the size of stack:  3

# %%
class Stack:
  def __init__(self):
    self.stack = []

  def push(self, element):
    self.stack.append(element)

  def pop(self):
    if self.isEmpty():
      return "Stack is empty"
    return self.stack.pop()

  def peek(self):
    if self.isEmpty():
      return "Stack is empty"
    return self.stack[-1]

  def isEmpty(self):
    return len(self.stack) == 0

  def size(self):
    return len(self.stack)

# Create a stack
myStack = Stack()

myStack.push('A')
myStack.push('B')
myStack.push('C')

print("Stack: ", myStack.stack)
print("Pop: ", myStack.pop())
print("Stack after Pop: ", myStack.stack)
print("Peek: ", myStack.peek())
print("isEmpty: ", myStack.isEmpty())
print("Size: ", myStack.size())
# Out:
# Stack:  ['A', 'B', 'C']
# Pop:  C
# Stack after Pop:  ['A', 'B']
# Peek:  B
# isEmpty:  False
# Size:  2
