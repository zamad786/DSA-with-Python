# %% [markdown]
# <a href="https://colab.research.google.com/github/zamad786/DSA-with-Python/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = []
print(type(x))
y = [1,2,3,4,5,6,"abc"]
print(type(y))
z = [1,2,3.2,"abc",True]
print(type(z))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
x = [9, 12, 7, 4, 11]

# Add element:
x.append(1)
print("data with 1:", x)
# Sort list ascending:
x.sort()
print("now data is sorted and 1 is entered too:", x)
# Out:
# data with 1: [9, 12, 7, 4, 11, 1]
# now data is sorted and 1 is entered too: [1, 4, 7, 9, 11, 12]
